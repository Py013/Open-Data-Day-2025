# %% [markdown]
# Instalação dos pacotes necessários para conexão com o site https://basedosdados.org/.org

# %%
# Instalação do pacote de conexão do google
#!pip install gql

# %%
# Instalação do pacote da base dos dados
#!pip install basedosdados

# %% [markdown]
# Importação das bibliotecas

# %%
# Biblioteca que conecta no site base dos dados
import basedosdados as bd

# %%
# Biblioteca pandas
import pandas as pd

# %%
# Carrega o dataset da base dos dados
df_ideb=bd.read_table(dataset_id='br_inep_ideb',
                      table_id='escola',
                      billing_project_id='opendataday2025')
# Out:
# Downloading: 100%|██████████|

# %%
# Verifica uma amostra dos dados carregados do ideb
df_ideb.head(5)
# Out:
#     ano sigla_uf id_municipio id_escola       rede       ensino  \
# 0  2017       RO      1100205  11000384   estadual        medio
# 1  2023       RO      1100205  11000384   estadual  fundamental
# 2  2015       RO      1100346  11000589  municipal  fundamental
# 3  2019       RO      1100346  11000589  municipal  fundamental
# 4  2019       RO      1100205  11000678   estadual  fundamental
#
#    anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0     todos (1-4)            52.8              0.535477                   NaN
# 1    finais (6-9)             NaN                   NaN                   NaN
# 2  iniciais (1-5)             NaN                   NaN                   NaN
# 3  iniciais (1-5)             NaN                   NaN                   NaN
# 4    finais (6-9)             NaN                   NaN                   NaN
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# ...

# %%
# Comando para conhecer o dataframe.
df_ideb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1164507 entries, 0 to 1164506
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   ano                          1164507 non-null  Int64
#  1   sigla_uf                     1164507 non-null  object
#  2   id_municipio                 1164507 non-null  object
#  3   id_escola                    1164507 non-null  object
#  4   rede                         1164507 non-null  object
#  5   ensino                       1164507 non-null  object
#  6   anos_escolares               1164507 non-null  object
#  7   taxa_aprovacao               814263 non-null   float64
#  8   indicador_rendimento         814214 non-null   float64
#  9   nota_saeb_matematica         705490 non-null   float64
#  10  nota_saeb_lingua_portuguesa  705490 non-null   float64
#  11  nota_saeb_media_padronizada  705490 non-null   float64
# ...

# %% [markdown]
# Exploração dos Dados

# %% [markdown]
# Conheçendo as variáves categóricas

# %%
df_ideb["ensino"].unique()
# Out:
# array(['medio', 'fundamental'], dtype=object)

# %%
df_ideb["rede"].unique()
# Out:
# array(['estadual', 'municipal', 'privada', 'federal'], dtype=object)

# %%
df_ideb["anos_escolares"].unique()
# Out:
# array(['todos (1-4)', 'finais (6-9)', 'iniciais (1-5)'], dtype=object)

# %% [markdown]
# Variáveis Númericas

# %%
df_ideb.describe()
# Out:
#                ano  taxa_aprovacao  indicador_rendimento  \
# count    1164507.0   814263.000000         814214.000000
# mean   2014.488668       88.662148              0.884721
# std       5.797153       11.124104              0.114070
# min         2005.0        0.000000              0.013085
# 25%         2009.0       82.900000              0.826277
# 50%         2015.0       91.800000              0.917505
# 75%         2019.0       97.500000              0.975278
# max         2023.0      100.000000              1.000000
#
#        nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# count         705490.000000                705490.000000
# mean             225.529787                   216.468304
# std               34.396824                    37.658455
# min               99.890000                   103.660000
# 25%              200.660000                   187.640000
# 50%              227.220000                   217.500000
# ...

# %% [markdown]
# Desafio:
#
#
# 1) Como fitrar somente as escolas da baixada santista?.
#
# 2) Nesta base tem somente os "Id_escola". Como identifica-lá?.
#
# 3) Identificada a escola, obter os dados de localização.
#
# 4) Podemos ver no mapa os seguinte dados:
#
#
# Exemplo:
#
# Onde está as escolas com pior desempenho?.
#
# Onde está as escolas com o melhor desempenho?.
#
# Onde está localizadas as escolas públicas?.
